# %% [markdown]
# ---
# title: "NumPy vs PyTorch"
# date: 2024-07-27
# format: html
# ---

# %% [markdown]
# description

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# %% [markdown]
# asdasdad

# %%
arr = np.random.rand(100)

# %%
plt.figure(figsize=(10, 6))
plt.plot(arr)
